# %%
from process_receipt.receipt import Receipt
from process_receipt.GUI import graph_receipt

# %%
file_path = './test_files/OCR1.txt'

receipt = Receipt(file_path)

# %%
receipt
# Out:
# {
#    "address": "LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR (MR DIY TESCO TERBAU)",
#    "company": "MR D.T.Y. (JOHOR) SDN BHD",
#    "date": "12-01-19",
#    "line_items": [
#       {
#          "price": "19.00",
#          "quantity": "1",
#          "sku": "8970669",
#          "total": "19.00"
#       },
#       {
#          "price": "8.02",
#          "quantity": "1",
#          "sku": "9066468",
#          "total": "8.02"
#       },
#       {
#          "price": "3.02",
#          "quantity": "1",
#          "sku": "9557031100236",
#          "total": "3.02"
#       },
#       {
#          "price": "3.88",
#          "quantity": "1",
#          "sku": "6935818350846",
#          "total": "3.88"
#       }
#    ],
#    "total": "33.90"
# }

# %%
graph_receipt(receipt)
# Out:
# <PIL.Image.Image image mode=RGB size=441x904>
